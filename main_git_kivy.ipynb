# %%
# %pwd 
# %cd /content/drive/MyDrive
# %pwd
# Out:
# /content/drive/MyDrive
# '/content/drive/MyDrive'

# %%
# !git clone https://github.com/TLQB/kivy-projects.git
# Out:
# Cloning into 'kivy-projects'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# %cd kivy-projects
# %pwd
# Out:
# /content/drive/MyDrive/kivy-projects
# '/content/drive/MyDrive/kivy-projects'

# %%
# !git config --global user.email "tranlequybaotk12@gmail.com"
# !git config --global user.name "TLQB"

# %%
# !git add .
# Out:
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> buildozer
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached buildozer
# hint:
# hint: See "git help submodule" for more information.

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	new file:   main_git_kivy.ipynb

# %%
# !git commit -m "first config"
# Out:
# [master 27877ab] first config
#  1 file changed, 1 insertion(+)
#  create mode 100644 main_git_kivy.ipynb

# %%
# !git branch
# Out:
# * develop

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/kivy-projects/.git/

# %%
# !git remote add origin https://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@github.com/TLQB/kivy-projects.git

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/TLQB/kivy-projects.git (fetch)
# origin	https://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@github.com/TLQB/kivy-projects.git (push)

# %%
# !git fetch

# %%
# !git pull origin develop
# Out:
# From https://github.com/TLQB/kivy-projects
#  * branch            develop    -> FETCH_HEAD
# Already up to date.

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/kivy-projects'

# %%
# !git clone https://github.com/kivy/buildozer.git
# Out:
# Cloning into 'buildozer'...
# remote: Enumerating objects: 4355, done.
# remote: Counting objects: 100% (346/346), done.
# remote: Compressing objects: 100% (179/179), done.
# remote: Total 4355 (delta 224), reused 269 (delta 165), pack-reused 4009
# Receiving objects: 100% (4355/4355), 1.50 MiB | 2.95 MiB/s, done.
# Resolving deltas: 100% (2736/2736), done.

# %%
# !git rm -rf --cached buildozer
# Out:
# rm 'buildozer'
